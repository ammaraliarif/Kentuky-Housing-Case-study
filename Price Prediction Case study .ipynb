# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mpl_toolkits
# %matplotlib inline

# %%
data = pd.read_csv(r"kc_house_data.csv")

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
data['bedrooms'].value_counts().plot(kind='bar')
plt.title('Number of Bedrooms')
plt.xlabel('Bedrooms')
plt.ylabel('Count')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.figure(figsize=(10,10),dpi=80)
sns.jointplot(x=data.lat.values,y=data.long.values,size=10)
plt.xlabel('Latitude',fontsize=12)
plt.ylabel('Longitude',fontsize=12)
plt.show()
sns.despine
# Out:
# C:\Users\Owner\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\Owner\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.figure(figsize=(8,8),dpi=80)
plt.scatter(data.price,data.sqft_living)
plt.title('Price Vs Square Feet')
# Out:
# Text(0.5,1,'Price Vs Square Feet')

# %%
plt.figure(figsize=(8,8),dpi=80)
plt.scatter(data.price,data.lat)
plt.xlabel('Price')
plt.ylabel('Latitude')
plt.title('Price Vs Latitude')
# Out:
# Text(0.5,1,'Price Vs Latitude')

# %%
plt.figure(figsize=(8,8),dpi=80)
plt.scatter(data.bedrooms,data.price)
plt.xlabel('Bedrooms')
plt.ylabel('Price')
plt.show()
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.figure(figsize=(8,8),dpi=80)
plt.scatter(data['sqft_living']+data['sqft_above']+data['sqft_basement'],data['price'])
plt.xlabel('Total Construction Sqft')
plt.ylabel('Price')
plt.show()

# %%
data.floors.value_counts().plot(kind='bar')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.cross_validation import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

# %%
linreg = LinearRegression()

# %%
tdata = data.drop(['id','price','date'],axis=1)
conv_dates = [1 if values == 2014 else 0 for values in data.date]
labels = data['price']
#tdata['date'] = conv_dates

# %%
X_train , X_test , y_train , y_test = train_test_split(tdata , labels, test_size = 0.2 , random_state = 42 )

# %%
linreg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
linreg.score(X_test,y_test)
# Out:
# 0.7011904448878343

# %%
#Cross Validation 
cv_results = cross_val_score(linreg , tdata, labels, cv=5)
print(cv_results)
print(np.mean(cv_results))
# Out:
# [0.69615715 0.69103231 0.69273185 0.70769239 0.68534044]
# 0.6945908283283428

# %%
# Lasso Feature selection
#removing the alpha generates similar score otherwise alpha=0.1
#since no covergence warning is given when alpha is remved I removed the alpha and let sklearn figure it out 
lasso = Lasso(normalize=True)
names = tdata.columns
lasso_coef = lasso.fit(tdata, labels).coef_
plt.plot(range(len(names)), lasso_coef)
plt.xticks(range(len(names)), names,rotation = 90)
plt.ylabel('Coefficients')
plt.show()

# %%
lasso.fit(X_train,y_train)
lasso_pred = lasso.predict(X_test)
lasso_score= lasso.score(X_test,y_test)
cv_results_lasso = cross_val_score(lasso, tdata, labels, cv=5)
print(lasso_score)
print(cv_results_lasso)
print(np.mean(cv_results_lasso))
# Out:
# 0.7010860555517602
# [0.69606605 0.69094743 0.6927807  0.70778478 0.68551176]
# 0.6946181431281426

# %%
#Ridge regression
ridge = Ridge(alpha=0.1,normalize=True)
ridge.fit(X_train , y_train)
ridge_pred = ridge.predict(X_test)
ridge_score=ridge.score(X_test, y_test)
cv_results_ridge= cross_val_score(ridge, tdata, labels, cv=5)
print(ridge_score)
print(cv_results_ridge)
print(np.mean(cv_results_ridge))
# Out:
# 0.6957386488603137
# [0.69052768 0.68481019 0.69415717 0.71075148 0.68325224]
# 0.6926997510255835
